# %% [markdown]
# # Logistic Regression (Logistik Reqressiya)

# %% [markdown]
# Bu yazıda Logistik Reqressiyanın əsasları və Pythonda tətbiq olunmasını öyrənəcəksiniz.Logistik reqressiya əsasən Rəhbərli Öyrənmə alqoritmidir.Bir təsnifat(sinifləndirmə) problemində hədəf dəyişən (və ya çıxış), y, verilən xüsusiyyətlər dəsti (və ya giriş) üçün yalnız diskret dəyərlər götürə bilər, X.
# Logistik reqress bir reqressiya modelidir. Model verilmiş məlumat girişinin “1” kimi nömrələnmiş kateqoriyaya aid olma ehtimalını proqnozlaşdırmaq üçün reqressiya modelini qurur.Xətti reqressiya məlumatların xətti bir funksiya izlədiyini güman etdiyi kimi, Logistik reqressiya da sigmoid funksiyasından istifadə edərək məlumatları modelləşdirir.Aşağıdakı rəsmə diqqət etsəniz logistik reqressiya neyron şəbəkəsinə bənzəyir.

# %%
from IPython.display import Image
Image(filename='image/log.png')

# %%
from IPython.display import Image
Image(filename='image/sigmoid-function-300x138.png')

# %% [markdown]
# reqressiya yalnız bir qərar həddi şəkilə gətirildikdə təsnifat texnikasına çevrilir. Dərəcənin təyin edilməsi Logistik reqressiyanın çox vacib bir tərəfidir və təsnifat probleminin özündən asılıdır.

# %% [markdown]
# 1) Low Precision/High Recall: (Aşağı Həssaslıq / Yüksək Xatırlatma)

# %% [markdown]
# Yalnış pozitivlərin sayını mütləq azaltmadan saxta neqativlərin sayını azaltmaq istədiyimiz tətbiqlərdə, həssaslığın və ya Xatırlatmanın aşağı dəyəri olan qərar dəyərini seçirik. Məsələn, bir xərçəng diaqnozu tətbiqində, xəstənin səhvən xərçəng diaqnozu qoyulubsa, çox əhəmiyyət vermədən təsirlənmiş hər hansı bir xəstənin təsirlənməmiş kimi təsnif edilməsini istəmirik. Bunun səbəbi, xərçəngin olmaması sonrakı tibbi xəstəliklər tərəfindən aşkar edilə bilər, ancaq xəstəliyin mövcudluğu rədd edilmiş bir namizəddə aşkar edilə bilməz.

# %% [markdown]
# 2. High Precision/Low Recall: (Yüksək Həssaslıq/aşağı xatırlatma)

# %% [markdown]
# Mütləq saxta neqativlərin sayını azaltmadan saxta pozitivlərin sayını azaltmaq istədiyimiz tətbiqlərdə, həssaslıq və ya geri çağırmanın yüksək dəyəri olan qərar dəyərini seçirik. Məsələn, müştərilərin fərdi reklamlara müsbət və ya mənfi reaksiya verəcəklərini təsnif etsək, müştərinin reklamentinə müsbət reaksiya göstərəcəyinə tam əmin olmaq istəyirik, çünki əks halda mənfi reaksiya müştəridən potensial satışa səbəb ola bilər .

# %% [markdown]
# ## Types of logistic regression-Kategoriyaların sayına görə Logistik reqressiya:

# %% [markdown]
# 1) <strong>binomial</strong>: hədəf dəyişən yalnız iki mümkün növə sahib ola bilər: "qalib" və "zərər", "keçmək" və "uğursuz", "ölü" və "diri" və s. təmsil edə bilən "0" və ya "1" (binar klassifikasiya)

# %% [markdown]
# 2) <strong>multinomial</strong>: hədəf dəyişən 3 və ya daha çox mümkün növə sahib ola bilər, "xərçəng xəstəliyi" və "xəstəlik B qrupu" və "xəstəlik C qrupu" kimi.

# %% [markdown]
# 3) <strong>ordinal</strong>-nizamlı: sifariş edilmiş kateqoriyalarla hədəf dəyişənləri ilə birbaşa əlaqəli olması. Məsələn, bir test balı aşağıdakı kimi təsnif edilə bilər: "çox zəif", "yoxsul", "yaxşı", "çox yaxşı". Burada hər kateqoriyaya 0, 1, 2, 3 kimi bir xal verilə bilər.
